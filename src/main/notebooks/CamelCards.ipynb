// %%
enum class HandType {
    FLUSH, KARE, FULL, THREE, TWO_PAIR, PAIR, HIGH
}

val cards = listOf("A", "K", "Q", "J", "T", "9", "8", "7", "6", "5", "4", "3", "2")


data class Game(val hand: Hand, val bid: Int) : Comparable<Game> {
    override fun compareTo(other: Game): Int {
        val result = hand.type.compareTo(other.hand.type)
        if (result == 0) {
            return hand.compareTo(other.hand)
        }
        return result
    }

}

class Hand(val handRep: String) : Comparable<Hand> {

    var hand: List<String>
    var type: HandType = HandType.HIGH

    init {
        hand = ordered(handRep)
        type = calculateType()
    }

    private fun calculateType(): HandType {
        val groupedHand: Map<String, Int> = hand.groupingBy { it }.eachCount()
        if (groupedHand.size == 1) {
            return HandType.FLUSH
        }

        if (groupedHand.size == 2) {
            if (groupedHand.values.any { it == 3 }) {
                return HandType.FULL
            } else if (groupedHand.values.any { it == 4 }) {
                return HandType.KARE
            }
        }

        if (groupedHand.size == 3) {
            if (groupedHand.values.any { it == 3 }) {
                return HandType.THREE
            } else {
                return HandType.TWO_PAIR
            }
        }

        if (groupedHand.size == 4) {
            return HandType.PAIR
        }

        if (groupedHand.size == 5) {
            return HandType.HIGH
        }
        return HandType.HIGH
    }

    private fun ordered(handRep: String): List<String> {
        return handRep.toList().sortedBy { cards.indexOf(it.toString()) }.map { it.toString() }
    }

    override fun compareTo(other: Hand): Int {

        if (handRep == other.handRep) {
            return 0
        }
        
        handRep.zip(other.handRep).forEach {
            if (cards.indexOf(it.first.toString()) > cards.indexOf(it.second.toString())) {
                return 1
            } else if (cards.indexOf(it.first.toString()) < cards.indexOf(it.second.toString())) {
                return -1
            }
        }
        return -1
    
    }

    override fun toString(): String {
        return "Hand(hand='$handRep', type=$type)"
    }
}

fun part1() {

    val lines: List<String> = ReadInputHelper.readLinesFromResource("/twentythree/day7/input.txt")

    lines
            .map { it.split(' ') }
            .map { Game(Hand(it[0]), it[1].toInt()) }
            .sortedDescending()
            .foldIndexed(0) { index: Int, acc: Int, game: Game ->
                val intermidiate = game.bid * (index + 1)
                val result = acc + intermidiate
                result
            }
            .let { println(it) }
}

part1()
// Out:
// Game(hand=Hand(hand='2376K', type=HIGH), bid=641)
// Game(hand=Hand(hand='246QJ', type=HIGH), bid=752)
// Game(hand=Hand(hand='2497T', type=HIGH), bid=786)
// Game(hand=Hand(hand='24T7K', type=HIGH), bid=758)
// Game(hand=Hand(hand='24JAT', type=HIGH), bid=495)
// Game(hand=Hand(hand='26TQ9', type=HIGH), bid=760)
// Game(hand=Hand(hand='27438', type=HIGH), bid=509)
// Game(hand=Hand(hand='285J7', type=HIGH), bid=246)
// Game(hand=Hand(hand='28T4Q', type=HIGH), bid=398)
// Game(hand=Hand(hand='28JK6', type=HIGH), bid=926)
// Game(hand=Hand(hand='29QA4', type=HIGH), bid=847)
// Game(hand=Hand(hand='2T483', type=HIGH), bid=710)
// Game(hand=Hand(hand='2Q93T', type=HIGH), bid=659)
// Game(hand=Hand(hand='2K45T', type=HIGH), bid=415)
// Game(hand=Hand(hand='2K546', type=HIGH), bid=963)
// Game(hand=Hand(hand='32J54', type=HIGH), bid=289)
// Game(hand=Hand(hand='32JQT', type=HIGH), bid=443)
// Game(hand=Hand(hand='34Q6J', type=HIGH), bid=607)
// Game(hand=Hand(hand='35698', type=HIGH), bid=515)
// Game(hand=Hand(hand='35J7T', type=HIGH), bid=668)
// Game(hand=Hand(hand='3725J', type=HIGH), bid=579)
// Game(hand=Hand(hand='37958', type=HIGH), bid=62)
// Game(hand=Hand(hand='392AK', type=HIGH), bid=558)
// Game(hand=Hand(hand='397K2', type=HIGH), bid=370)
// Game(hand=Hand(hand='39Q42', type=HIGH), bid=3)
// Game(hand=Hand(hand='3TK47', type=HIGH), bid=617)
// Game(hand=Hand(hand='3J798', type=HIGH), bid=92)
// Game(hand=Hand(hand='3JK4Q', type=HIGH), bid=204)
// Game(hand=Hand(hand='3JA4K', type=HIGH), bid=902)
// Game(hand=Hand(hand='3Q958', type=HIGH), bid=537)
// Game(hand=Hand(hand='3Q9K7', type=HIGH), bid=277)
// Game(hand=Hand(hand='3QA85', type=HIGH), bid=554)
// Game(hand=Hand(hand='3A68T', type=HIGH), bid=461)
// Game(hand=Hand(hand='423T5', type=HIGH), bid=354)
// Game(hand=Hand(hand='4273K', type=HIGH), bid=689)
// Game(hand=Hand(hand='4278A', type=HIGH), bid=487)
// Game(hand=Hand(hand='42JT5', type=HIGH), bid=31)
// Game(hand=Hand(hand='43T68', type=HIGH), bid=640)
// Game(hand=Hand(hand='43AQT', type=HIGH), bid=405)
// Game(hand=Hand(hand='47869', type=HIGH), bid=529)
// Game(hand=Hand(hand='4836K', type=HIGH), bid=285)
// Game(hand=Hand(hand='4897Q', type=HIGH), bid=769)
// Game(hand=Hand(hand='492TQ', type=HIGH), bid=105)
// Game(hand=Hand(hand='492AK', type=HIGH), bid=199)
// Game(hand=Hand(hand='49T32', type=HIGH), bid=304)
// Game(hand=Hand(hand='49J7T', type=HIGH), bid=764)
// Game(hand=Hand(hand='4TA52', type=HIGH), bid=448)
// Game(hand=Hand(hand='4J3TK', type=HIGH), bid=673)
// Game(hand=Hand(hand='4JAK5', type=HIGH), bid=827)
// Game(hand=Hand(hand='4Q6J8', type=HIGH), bid=454)
// Game(hand=Hand(hand='4K75A', type=HIGH), bid=126)
// Game(hand=Hand(hand='4K956', type=HIGH), bid=546)
// Game(hand=Hand(hand='4KQ63', type=HIGH), bid=273)
// Game(hand=Hand(hand='4A237', type=HIGH), bid=841)
// Game(hand=Hand(hand='52A76', type=HIGH), bid=851)
// Game(hand=Hand(hand='532A8', type=HIGH), bid=598)
// Game(hand=Hand(hand='5438J', type=HIGH), bid=331)
// Game(hand=Hand(hand='56TQ7', type=HIGH), bid=911)
// Game(hand=Hand(hand='56J42', type=HIGH), bid=962)
// Game(hand=Hand(hand='573A9', type=HIGH), bid=946)
// Game(hand=Hand(hand='57TA2', type=HIGH), bid=139)
// Game(hand=Hand(hand='5896A', type=HIGH), bid=463)
// Game(hand=Hand(hand='58T43', type=HIGH), bid=653)
// Game(hand=Hand(hand='594JT', type=HIGH), bid=7)
// Game(hand=Hand(hand='5984T', type=HIGH), bid=657)
// Game(hand=Hand(hand='5T6J2', type=HIGH), bid=479)
// Game(hand=Hand(hand='5TQJ4', type=HIGH), bid=447)
// Game(hand=Hand(hand='5TQK3', type=HIGH), bid=984)
// Game(hand=Hand(hand='5TKA7', type=HIGH), bid=436)
// Game(hand=Hand(hand='5J726', type=HIGH), bid=697)
// Game(hand=Hand(hand='5Q2K9', type=HIGH), bid=251)
// Game(hand=Hand(hand='5QK67', type=HIGH), bid=567)
// Game(hand=Hand(hand='5K326', type=HIGH), bid=578)
// Game(hand=Hand(hand='5K489', type=HIGH), bid=320)
// Game(hand=Hand(hand='635J9', type=HIGH), bid=157)
// Game(hand=Hand(hand='65482', type=HIGH), bid=559)
// Game(hand=Hand(hand='658T7', type=HIGH), bid=643)
// Game(hand=Hand(hand='678T9', type=HIGH), bid=266)
// Game(hand=Hand(hand='69K73', type=HIGH), bid=48)
// Game(hand=Hand(hand='6J427', type=HIGH), bid=635)
// Game(hand=Hand(hand='6J578', type=HIGH), bid=411)
// Game(hand=Hand(hand='6J823', type=HIGH), bid=407)
// Game(hand=Hand(hand='6J8KT', type=HIGH), bid=924)
// Game(hand=Hand(hand='6JK49', type=HIGH), bid=922)
// Game(hand=Hand(hand='6QJ93', type=HIGH), bid=859)
// Game(hand=Hand(hand='6QKT5', type=HIGH), bid=73)
// Game(hand=Hand(hand='6A738', type=HIGH), bid=70)
// Game(hand=Hand(hand='73642', type=HIGH), bid=458)
// Game(hand=Hand(hand='7384T', type=HIGH), bid=820)
// Game(hand=Hand(hand='738JQ', type=HIGH), bid=135)
// Game(hand=Hand(hand='7468K', type=HIGH), bid=460)
// Game(hand=Hand(hand='74TJ8', type=HIGH), bid=466)
// Game(hand=Hand(hand='75Q2J', type=HIGH), bid=974)
// Game(hand=Hand(hand='75AJ4', type=HIGH), bid=152)
// Game(hand=Hand(hand='79285', type=HIGH), bid=174)
// Game(hand=Hand(hand='79354', type=HIGH), bid=267)
// Game(hand=Hand(hand='79654', type=HIGH), bid=938)
// Game(hand=Hand(hand='79J82', type=HIGH), bid=60)
// Game(hand=Hand(hand='79AKQ', type=HIGH), bid=853)
// Game(hand=Hand(hand='7J459', type=HIGH), bid=944)
// Game(hand=Hand(hand='7J62Q', type=HIGH), bid=209)
// Game(hand=Hand(hand='7J62K', type=HIGH), bid=494)
// Game(hand=Hand(hand='7J643', type=HIGH), bid=857)
// Game(hand=Hand(hand='7Q25K', type=HIGH), bid=809)
// Game(hand=Hand(hand='7A329', type=HIGH), bid=991)
// Game(hand=Hand(hand='7A3K9', type=HIGH), bid=886)
// Game(hand=Hand(hand='82749', type=HIGH), bid=569)
// Game(hand=Hand(hand='832Q7', type=HIGH), bid=388)
// Game(hand=Hand(hand='83T4J', type=HIGH), bid=720)
// Game(hand=Hand(hand='8927A', type=HIGH), bid=516)
// Game(hand=Hand(hand='893Q7', type=HIGH), bid=471)
// Game(hand=Hand(hand='8TQ53', type=HIGH), bid=988)
// Game(hand=Hand(hand='8A47K', type=HIGH), bid=998)
// Game(hand=Hand(hand='924T6', type=HIGH), bid=713)
// Game(hand=Hand(hand='925JK', type=HIGH), bid=243)
// Game(hand=Hand(hand='926JA', type=HIGH), bid=203)
// Game(hand=Hand(hand='92JAQ', type=HIGH), bid=654)
// Game(hand=Hand(hand='9478K', type=HIGH), bid=179)
// Game(hand=Hand(hand='947JQ', type=HIGH), bid=539)
// Game(hand=Hand(hand='96AQ4', type=HIGH), bid=917)
// Game(hand=Hand(hand='9765J', type=HIGH), bid=473)
// Game(hand=Hand(hand='97QT2', type=HIGH), bid=453)
// Game(hand=Hand(hand='97QJ2', type=HIGH), bid=347)
// Game(hand=Hand(hand='97KA6', type=HIGH), bid=106)
// Game(hand=Hand(hand='98T4Q', type=HIGH), bid=967)
// Game(hand=Hand(hand='98K7T', type=HIGH), bid=211)
// Game(hand=Hand(hand='9TJ64', type=HIGH), bid=147)
// Game(hand=Hand(hand='9JTKQ', type=HIGH), bid=718)
// Game(hand=Hand(hand='9Q726', type=HIGH), bid=695)
// Game(hand=Hand(hand='9QJKA', type=HIGH), bid=305)
// Game(hand=Hand(hand='9K27A', type=HIGH), bid=881)
// Game(hand=Hand(hand='T287J', type=HIGH), bid=181)
// Game(hand=Hand(hand='T465K', type=HIGH), bid=927)
// Game(hand=Hand(hand='T46K2', type=HIGH), bid=923)
// Game(hand=Hand(hand='T543J', type=HIGH), bid=602)
// Game(hand=Hand(hand='T6372', type=HIGH), bid=580)
// Game(hand=Hand(hand='T63JK', type=HIGH), bid=763)
// Game(hand=Hand(hand='T7864', type=HIGH), bid=6)
// Game(hand=Hand(hand='T7Q6A', type=HIGH), bid=671)
// Game(hand=Hand(hand='T936A', type=HIGH), bid=256)
// Game(hand=Hand(hand='T9K52', type=HIGH), bid=816)
// Game(hand=Hand(hand='TJ9A2', type=HIGH), bid=177)
// Game(hand=Hand(hand='TK82A', type=HIGH), bid=229)
// Game(hand=Hand(hand='TK8A9', type=HIGH), bid=155)
// Game(hand=Hand(hand='J39T7', type=HIGH), bid=986)
// Game(hand=Hand(hand='J47K3', type=HIGH), bid=867)
// Game(hand=Hand(hand='JT69K', type=HIGH), bid=620)
// Game(hand=Hand(hand='JT7A6', type=HIGH), bid=156)
// Game(hand=Hand(hand='JTQ72', type=HIGH), bid=426)
// Game(hand=Hand(hand='JQ568', type=HIGH), bid=23)
// Game(hand=Hand(hand='JK68A', type=HIGH), bid=166)
// Game(hand=Hand(hand='JA467', type=HIGH), bid=978)
// Game(hand=Hand(hand='JA5Q9', type=HIGH), bid=112)
// Game(hand=Hand(hand='JAQT7', type=HIGH), bid=708)
// Game(hand=Hand(hand='Q2475', type=HIGH), bid=324)
// Game(hand=Hand(hand='Q2685', type=HIGH), bid=500)
// Game(hand=Hand(hand='Q2748', type=HIGH), bid=477)
// Game(hand=Hand(hand='Q29K6', type=HIGH), bid=889)
// Game(hand=Hand(hand='Q2A65', type=HIGH), bid=555)
// Game(hand=Hand(hand='Q38K5', type=HIGH), bid=301)
// Game(hand=Hand(hand='Q5482', type=HIGH), bid=721)
// Game(hand=Hand(hand='Q5892', type=HIGH), bid=783)
// Game(hand=Hand(hand='Q593K', type=HIGH), bid=702)
// Game(hand=Hand(hand='Q652K', type=HIGH), bid=34)
// Game(hand=Hand(hand='Q7T82', type=HIGH), bid=925)
// Game(hand=Hand(hand='Q7A4K', type=HIGH), bid=584)
// Game(hand=Hand(hand='Q82J4', type=HIGH), bid=966)
// Game(hand=Hand(hand='Q975T', type=HIGH), bid=123)
// Game(hand=Hand(hand='Q9764', type=HIGH), bid=74)
// Game(hand=Hand(hand='Q9JT6', type=HIGH), bid=275)
// Game(hand=Hand(hand='QT642', type=HIGH), bid=704)
// Game(hand=Hand(hand='QTA68', type=HIGH), bid=939)
// Game(hand=Hand(hand='QA8J4', type=HIGH), bid=956)
// Game(hand=Hand(hand='QAJ39', type=HIGH), bid=989)
// Game(hand=Hand(hand='K4AJT', type=HIGH), bid=450)
// Game(hand=Hand(hand='K532T', type=HIGH), bid=328)
// Game(hand=Hand(hand='K5J4Q', type=HIGH), bid=941)
// Game(hand=Hand(hand='K6T95', type=HIGH), bid=63)
// Game(hand=Hand(hand='K6QT7', type=HIGH), bid=904)
// Game(hand=Hand(hand='K7J84', type=HIGH), bid=213)
// Game(hand=Hand(hand='K7JT4', type=HIGH), bid=79)
// Game(hand=Hand(hand='K8J72', type=HIGH), bid=176)
// Game(hand=Hand(hand='K9J8A', type=HIGH), bid=104)
// Game(hand=Hand(hand='KTJ27', type=HIGH), bid=107)
// Game(hand=Hand(hand='KJ839', type=HIGH), bid=187)
// Game(hand=Hand(hand='KQJ25', type=HIGH), bid=616)
// Game(hand=Hand(hand='KA263', type=HIGH), bid=666)
// Game(hand=Hand(hand='KA934', type=HIGH), bid=69)
// Game(hand=Hand(hand='KAT47', type=HIGH), bid=234)
// Game(hand=Hand(hand='KAT63', type=HIGH), bid=565)
// Game(hand=Hand(hand='A2563', type=HIGH), bid=446)
// Game(hand=Hand(hand='A2639', type=HIGH), bid=54)
// Game(hand=Hand(hand='A3J26', type=HIGH), bid=678)
// Game(hand=Hand(hand='A4238', type=HIGH), bid=982)
// Game(hand=Hand(hand='A4628', type=HIGH), bid=75)
// Game(hand=Hand(hand='A5628', type=HIGH), bid=438)
// Game(hand=Hand(hand='A5Q98', type=HIGH), bid=749)
// Game(hand=Hand(hand='A624Q', type=HIGH), bid=414)
// Game(hand=Hand(hand='A86K2', type=HIGH), bid=891)
// Game(hand=Hand(hand='A8796', type=HIGH), bid=101)
// Game(hand=Hand(hand='AT6Q9', type=HIGH), bid=726)
// Game(hand=Hand(hand='AJ79K', type=HIGH), bid=218)
// Game(hand=Hand(hand='AQ863', type=HIGH), bid=86)
// Game(hand=Hand(hand='AK8Q4', type=HIGH), bid=795)
// Game(hand=Hand(hand='AKJ5T', type=HIGH), bid=782)
// Game(hand=Hand(hand='2243T', type=PAIR), bid=13)
// Game(hand=Hand(hand='22683', type=PAIR), bid=94)
// Game(hand=Hand(hand='228JK', type=PAIR), bid=424)
// Game(hand=Hand(hand='22K53', type=PAIR), bid=829)
// Game(hand=Hand(hand='23537', type=PAIR), bid=663)
// Game(hand=Hand(hand='23949', type=PAIR), bid=995)
// Game(hand=Hand(hand='23KKQ', type=PAIR), bid=262)
// Game(hand=Hand(hand='24Q32', type=PAIR), bid=603)
// Game(hand=Hand(hand='27445', type=PAIR), bid=542)
// Game(hand=Hand(hand='27688', type=PAIR), bid=295)
// Game(hand=Hand(hand='29TTJ', type=PAIR), bid=665)
// Game(hand=Hand(hand='2J2K3', type=PAIR), bid=168)
// Game(hand=Hand(hand='2JK24', type=PAIR), bid=932)
// Game(hand=Hand(hand='2JK7J', type=PAIR), bid=393)
// Game(hand=Hand(hand='2JAKA', type=PAIR), bid=656)
// Game(hand=Hand(hand='2KKJA', type=PAIR), bid=255)
// Game(hand=Hand(hand='3229T', type=PAIR), bid=882)
// Game(hand=Hand(hand='336A2', type=PAIR), bid=905)
// Game(hand=Hand(hand='35242', type=PAIR), bid=8)
// Game(hand=Hand(hand='36835', type=PAIR), bid=582)
// Game(hand=Hand(hand='38539', type=PAIR), bid=491)
// Game(hand=Hand(hand='38J55', type=PAIR), bid=47)
// Game(hand=Hand(hand='39545', type=PAIR), bid=949)
// Game(hand=Hand(hand='3JKA3', type=PAIR), bid=271)
// Game(hand=Hand(hand='3QA44', type=PAIR), bid=850)
// Game(hand=Hand(hand='3K4QK', type=PAIR), bid=692)
// Game(hand=Hand(hand='42556', type=PAIR), bid=521)
// Game(hand=Hand(hand='44JT3', type=PAIR), bid=768)
// Game(hand=Hand(hand='44JAT', type=PAIR), bid=474)
// Game(hand=Hand(hand='44QJ3', type=PAIR), bid=711)
// Game(hand=Hand(hand='4574Q', type=PAIR), bid=618)
// Game(hand=Hand(hand='46365', type=PAIR), bid=761)
// Game(hand=Hand(hand='46A4J', type=PAIR), bid=93)
// Game(hand=Hand(hand='4TQ2T', type=PAIR), bid=864)
// Game(hand=Hand(hand='4Q5TQ', type=PAIR), bid=874)
// Game(hand=Hand(hand='4QJ88', type=PAIR), bid=102)
// Game(hand=Hand(hand='4KT49', type=PAIR), bid=151)
// Game(hand=Hand(hand='4A427', type=PAIR), bid=24)
// Game(hand=Hand(hand='4ATTJ', type=PAIR), bid=478)
// Game(hand=Hand(hand='4AATJ', type=PAIR), bid=173)
// Game(hand=Hand(hand='559KJ', type=PAIR), bid=71)
// Game(hand=Hand(hand='56J99', type=PAIR), bid=383)
// Game(hand=Hand(hand='57JA5', type=PAIR), bid=146)
// Game(hand=Hand(hand='5969Q', type=PAIR), bid=535)
// Game(hand=Hand(hand='599A4', type=PAIR), bid=798)
// Game(hand=Hand(hand='5T66A', type=PAIR), bid=723)
// Game(hand=Hand(hand='5TKJ5', type=PAIR), bid=249)
// Game(hand=Hand(hand='5J25T', type=PAIR), bid=652)
// Game(hand=Hand(hand='5J677', type=PAIR), bid=644)
// Game(hand=Hand(hand='5JJ62', type=PAIR), bid=869)
// Game(hand=Hand(hand='5Q538', type=PAIR), bid=10)
// Game(hand=Hand(hand='5K57A', type=PAIR), bid=149)
// Game(hand=Hand(hand='5K844', type=PAIR), bid=734)
// Game(hand=Hand(hand='5K9KJ', type=PAIR), bid=852)
// Game(hand=Hand(hand='5A56K', type=PAIR), bid=980)
// Game(hand=Hand(hand='5A6A4', type=PAIR), bid=250)
// Game(hand=Hand(hand='5AKA7', type=PAIR), bid=754)
// Game(hand=Hand(hand='62393', type=PAIR), bid=59)
// Game(hand=Hand(hand='63J93', type=PAIR), bid=87)
// Game(hand=Hand(hand='63K68', type=PAIR), bid=976)
// Game(hand=Hand(hand='65TTJ', type=PAIR), bid=410)
// Game(hand=Hand(hand='665T7', type=PAIR), bid=238)
// Game(hand=Hand(hand='66TAJ', type=PAIR), bid=258)
// Game(hand=Hand(hand='66QT9', type=PAIR), bid=81)
// Game(hand=Hand(hand='675J6', type=PAIR), bid=476)
// Game(hand=Hand(hand='67J7K', type=PAIR), bid=897)
// Game(hand=Hand(hand='688JT', type=PAIR), bid=698)
// Game(hand=Hand(hand='68TTJ', type=PAIR), bid=562)
// Game(hand=Hand(hand='69TK9', type=PAIR), bid=144)
// Game(hand=Hand(hand='6T9A9', type=PAIR), bid=890)
// Game(hand=Hand(hand='6TTAK', type=PAIR), bid=21)
// Game(hand=Hand(hand='6TKJT', type=PAIR), bid=701)
// Game(hand=Hand(hand='6J624', type=PAIR), bid=815)
// Game(hand=Hand(hand='6J63K', type=PAIR), bid=677)
// Game(hand=Hand(hand='6J65Q', type=PAIR), bid=367)
// Game(hand=Hand(hand='6J7T7', type=PAIR), bid=608)
// Game(hand=Hand(hand='6J86K', type=PAIR), bid=973)
// Game(hand=Hand(hand='6J8AJ', type=PAIR), bid=545)
// Game(hand=Hand(hand='6JT4T', type=PAIR), bid=908)
// Game(hand=Hand(hand='6QAQT', type=PAIR), bid=368)
// Game(hand=Hand(hand='6K629', type=PAIR), bid=208)
// Game(hand=Hand(hand='6K678', type=PAIR), bid=870)
// Game(hand=Hand(hand='6KT88', type=PAIR), bid=360)
// Game(hand=Hand(hand='6KK9J', type=PAIR), bid=621)
// Game(hand=Hand(hand='6A654', type=PAIR), bid=99)
// Game(hand=Hand(hand='6AJ26', type=PAIR), bid=839)
// Game(hand=Hand(hand='72A24', type=PAIR), bid=15)
// Game(hand=Hand(hand='739AA', type=PAIR), bid=465)
// Game(hand=Hand(hand='7427J', type=PAIR), bid=930)
// Game(hand=Hand(hand='7487Q', type=PAIR), bid=997)
// Game(hand=Hand(hand='74AAK', type=PAIR), bid=960)
// Game(hand=Hand(hand='76972', type=PAIR), bid=72)
// Game(hand=Hand(hand='76K27', type=PAIR), bid=408)
// Game(hand=Hand(hand='7748J', type=PAIR), bid=977)
// Game(hand=Hand(hand='776J3', type=PAIR), bid=517)
// Game(hand=Hand(hand='77T96', type=PAIR), bid=32)
// Game(hand=Hand(hand='7837J', type=PAIR), bid=167)
// Game(hand=Hand(hand='78J85', type=PAIR), bid=440)
// Game(hand=Hand(hand='79467', type=PAIR), bid=512)
// Game(hand=Hand(hand='7TAA8', type=PAIR), bid=716)
// Game(hand=Hand(hand='7J22K', type=PAIR), bid=84)
// Game(hand=Hand(hand='7J95J', type=PAIR), bid=935)
// Game(hand=Hand(hand='7KQQ2', type=PAIR), bid=913)
// Game(hand=Hand(hand='7A8K8', type=PAIR), bid=224)
// Game(hand=Hand(hand='7AATJ', type=PAIR), bid=627)
// Game(hand=Hand(hand='82384', type=PAIR), bid=469)
// Game(hand=Hand(hand='83236', type=PAIR), bid=472)
// Game(hand=Hand(hand='85952', type=PAIR), bid=392)
// Game(hand=Hand(hand='85J8A', type=PAIR), bid=114)
// Game(hand=Hand(hand='86K26', type=PAIR), bid=900)
// Game(hand=Hand(hand='8TTA3', type=PAIR), bid=563)
// Game(hand=Hand(hand='8J434', type=PAIR), bid=138)
// Game(hand=Hand(hand='8JKJ5', type=PAIR), bid=727)
// Game(hand=Hand(hand='8Q38J', type=PAIR), bid=464)
// Game(hand=Hand(hand='8Q39Q', type=PAIR), bid=790)
// Game(hand=Hand(hand='8A8T6', type=PAIR), bid=227)
// Game(hand=Hand(hand='8AJ8T', type=PAIR), bid=970)
// Game(hand=Hand(hand='94Q93', type=PAIR), bid=325)
// Game(hand=Hand(hand='958K8', type=PAIR), bid=797)
// Game(hand=Hand(hand='972AA', type=PAIR), bid=751)
// Game(hand=Hand(hand='97T7J', type=PAIR), bid=813)
// Game(hand=Hand(hand='98J9Q', type=PAIR), bid=513)
// Game(hand=Hand(hand='994T5', type=PAIR), bid=481)
// Game(hand=Hand(hand='994K8', type=PAIR), bid=245)
// Game(hand=Hand(hand='99J2K', type=PAIR), bid=948)
// Game(hand=Hand(hand='99Q63', type=PAIR), bid=196)
// Game(hand=Hand(hand='9T3TJ', type=PAIR), bid=994)
// Game(hand=Hand(hand='9J2J7', type=PAIR), bid=774)
// Game(hand=Hand(hand='9J398', type=PAIR), bid=201)
// Game(hand=Hand(hand='9J6QQ', type=PAIR), bid=552)
// Game(hand=Hand(hand='9J882', type=PAIR), bid=143)
// Game(hand=Hand(hand='9JTQJ', type=PAIR), bid=570)
// Game(hand=Hand(hand='9QQ54', type=PAIR), bid=364)
// Game(hand=Hand(hand='9QA9T', type=PAIR), bid=341)
// Game(hand=Hand(hand='9K848', type=PAIR), bid=212)
// Game(hand=Hand(hand='T2523', type=PAIR), bid=58)
// Game(hand=Hand(hand='T4335', type=PAIR), bid=190)
// Game(hand=Hand(hand='T442A', type=PAIR), bid=351)
// Game(hand=Hand(hand='T4JJK', type=PAIR), bid=329)
// Game(hand=Hand(hand='T5393', type=PAIR), bid=413)
// Game(hand=Hand(hand='T552A', type=PAIR), bid=103)
// Game(hand=Hand(hand='T558Q', type=PAIR), bid=215)
// Game(hand=Hand(hand='T74JJ', type=PAIR), bid=498)
// Game(hand=Hand(hand='T8332', type=PAIR), bid=340)
// Game(hand=Hand(hand='TTJ48', type=PAIR), bid=228)
// Game(hand=Hand(hand='TTJ63', type=PAIR), bid=207)
// Game(hand=Hand(hand='TJ4T7', type=PAIR), bid=314)
// Game(hand=Hand(hand='TJ7A7', type=PAIR), bid=551)
// Game(hand=Hand(hand='TQJT8', type=PAIR), bid=287)
// Game(hand=Hand(hand='TK2T3', type=PAIR), bid=740)
// Game(hand=Hand(hand='TK85T', type=PAIR), bid=198)
// Game(hand=Hand(hand='TA28A', type=PAIR), bid=117)
// Game(hand=Hand(hand='TAT72', type=PAIR), bid=49)
// Game(hand=Hand(hand='TAA63', type=PAIR), bid=485)
// Game(hand=Hand(hand='J2279', type=PAIR), bid=854)
// Game(hand=Hand(hand='J262K', type=PAIR), bid=66)
// Game(hand=Hand(hand='J2Q82', type=PAIR), bid=755)
// Game(hand=Hand(hand='J346J', type=PAIR), bid=699)
// Game(hand=Hand(hand='J3J58', type=PAIR), bid=486)
// Game(hand=Hand(hand='J3J6T', type=PAIR), bid=129)
// Game(hand=Hand(hand='J43KJ', type=PAIR), bid=40)
// Game(hand=Hand(hand='J443K', type=PAIR), bid=694)
// Game(hand=Hand(hand='J5242', type=PAIR), bid=268)
// Game(hand=Hand(hand='J5573', type=PAIR), bid=888)
// Game(hand=Hand(hand='J6256', type=PAIR), bid=676)
// Game(hand=Hand(hand='J6TJ8', type=PAIR), bid=389)
// Game(hand=Hand(hand='J6Q3Q', type=PAIR), bid=514)
// Game(hand=Hand(hand='J7898', type=PAIR), bid=729)
// Game(hand=Hand(hand='J7KKQ', type=PAIR), bid=358)
// Game(hand=Hand(hand='J8728', type=PAIR), bid=686)
// Game(hand=Hand(hand='J9J7Q', type=PAIR), bid=219)
// Game(hand=Hand(hand='JT2T7', type=PAIR), bid=756)
// Game(hand=Hand(hand='JT8KK', type=PAIR), bid=959)
// Game(hand=Hand(hand='JT9T7', type=PAIR), bid=700)
// Game(hand=Hand(hand='JTKK4', type=PAIR), bid=400)
// Game(hand=Hand(hand='JTAA5', type=PAIR), bid=762)
// Game(hand=Hand(hand='JJ45A', type=PAIR), bid=903)
// Game(hand=Hand(hand='JJ897', type=PAIR), bid=899)
// Game(hand=Hand(hand='JJTQ5', type=PAIR), bid=344)
// Game(hand=Hand(hand='JQ373', type=PAIR), bid=286)
// Game(hand=Hand(hand='JQ3KQ', type=PAIR), bid=981)
// Game(hand=Hand(hand='JK26K', type=PAIR), bid=658)
// Game(hand=Hand(hand='JK55Q', type=PAIR), bid=85)
// Game(hand=Hand(hand='JK6AA', type=PAIR), bid=133)
// Game(hand=Hand(hand='JK8A8', type=PAIR), bid=373)
// Game(hand=Hand(hand='JKK6Q', type=PAIR), bid=253)
// Game(hand=Hand(hand='JKK93', type=PAIR), bid=511)
// Game(hand=Hand(hand='JA338', type=PAIR), bid=125)
// Game(hand=Hand(hand='JA727', type=PAIR), bid=236)
// Game(hand=Hand(hand='JA774', type=PAIR), bid=687)
// Game(hand=Hand(hand='JA96A', type=PAIR), bid=806)
// Game(hand=Hand(hand='Q2253', type=PAIR), bid=810)
// Game(hand=Hand(hand='Q23A2', type=PAIR), bid=183)
// Game(hand=Hand(hand='Q362Q', type=PAIR), bid=958)
// Game(hand=Hand(hand='Q44J2', type=PAIR), bid=719)
// Game(hand=Hand(hand='Q4Q85', type=PAIR), bid=115)
// Game(hand=Hand(hand='Q4KJK', type=PAIR), bid=733)
// Game(hand=Hand(hand='Q727A', type=PAIR), bid=278)
// Game(hand=Hand(hand='Q8225', type=PAIR), bid=943)
// Game(hand=Hand(hand='Q866T', type=PAIR), bid=36)
// Game(hand=Hand(hand='QTQ95', type=PAIR), bid=170)
// Game(hand=Hand(hand='QJ38J', type=PAIR), bid=68)
// Game(hand=Hand(hand='QJTT2', type=PAIR), bid=614)
// Game(hand=Hand(hand='QQJ37', type=PAIR), bid=120)
// Game(hand=Hand(hand='K3665', type=PAIR), bid=237)
// Game(hand=Hand(hand='K3J5K', type=PAIR), bid=279)
// Game(hand=Hand(hand='K4577', type=PAIR), bid=772)
// Game(hand=Hand(hand='K4KT7', type=PAIR), bid=355)
// Game(hand=Hand(hand='K75JK', type=PAIR), bid=669)
// Game(hand=Hand(hand='K7796', type=PAIR), bid=637)
// Game(hand=Hand(hand='K787Q', type=PAIR), bid=296)
// Game(hand=Hand(hand='K7QAA', type=PAIR), bid=20)
// Game(hand=Hand(hand='K8285', type=PAIR), bid=879)
// Game(hand=Hand(hand='K898J', type=PAIR), bid=553)
// Game(hand=Hand(hand='K8KQ5', type=PAIR), bid=484)
// Game(hand=Hand(hand='KT3K8', type=PAIR), bid=585)
// Game(hand=Hand(hand='KT77J', type=PAIR), bid=427)
// Game(hand=Hand(hand='KJQ88', type=PAIR), bid=625)
// Game(hand=Hand(hand='KKT78', type=PAIR), bid=284)
// Game(hand=Hand(hand='KKJ9Q', type=PAIR), bid=432)
// Game(hand=Hand(hand='KA69A', type=PAIR), bid=403)
// Game(hand=Hand(hand='KAT4A', type=PAIR), bid=543)
// Game(hand=Hand(hand='KAK87', type=PAIR), bid=124)
// Game(hand=Hand(hand='A26J2', type=PAIR), bid=531)
// Game(hand=Hand(hand='A2J24', type=PAIR), bid=274)
// Game(hand=Hand(hand='A2A95', type=PAIR), bid=936)
// Game(hand=Hand(hand='A2AQ6', type=PAIR), bid=272)
// Game(hand=Hand(hand='A32JJ', type=PAIR), bid=55)
// Game(hand=Hand(hand='A43A9', type=PAIR), bid=349)
// Game(hand=Hand(hand='A46A8', type=PAIR), bid=319)
// Game(hand=Hand(hand='A496A', type=PAIR), bid=609)
// Game(hand=Hand(hand='A69J9', type=PAIR), bid=180)
// Game(hand=Hand(hand='A7JQA', type=PAIR), bid=651)
// Game(hand=Hand(hand='A8285', type=PAIR), bid=840)
// Game(hand=Hand(hand='A8A6Q', type=PAIR), bid=122)
// Game(hand=Hand(hand='AJ433', type=PAIR), bid=378)
// Game(hand=Hand(hand='AJ53A', type=PAIR), bid=672)
// Game(hand=Hand(hand='AQJTA', type=PAIR), bid=838)
// Game(hand=Hand(hand='AA978', type=PAIR), bid=64)
// Game(hand=Hand(hand='225KK', type=TWO_PAIR), bid=189)
// Game(hand=Hand(hand='22AKK', type=TWO_PAIR), bid=561)
// Game(hand=Hand(hand='22AA4', type=TWO_PAIR), bid=533)
// Game(hand=Hand(hand='2332J', type=TWO_PAIR), bid=113)
// Game(hand=Hand(hand='233A2', type=TWO_PAIR), bid=321)
// Game(hand=Hand(hand='2772A', type=TWO_PAIR), bid=896)
// Game(hand=Hand(hand='29295', type=TWO_PAIR), bid=45)
// Game(hand=Hand(hand='29323', type=TWO_PAIR), bid=309)
// Game(hand=Hand(hand='29729', type=TWO_PAIR), bid=353)
// Game(hand=Hand(hand='29K92', type=TWO_PAIR), bid=205)
// Game(hand=Hand(hand='2TK2K', type=TWO_PAIR), bid=975)
// Game(hand=Hand(hand='2J288', type=TWO_PAIR), bid=313)
// Game(hand=Hand(hand='2J2J5', type=TWO_PAIR), bid=801)
// Game(hand=Hand(hand='2J992', type=TWO_PAIR), bid=244)
// Game(hand=Hand(hand='2Q29Q', type=TWO_PAIR), bid=778)
// Game(hand=Hand(hand='2Q2TQ', type=TWO_PAIR), bid=972)
// Game(hand=Hand(hand='32Q3Q', type=TWO_PAIR), bid=342)
// Game(hand=Hand(hand='3355J', type=TWO_PAIR), bid=316)
// Game(hand=Hand(hand='33776', type=TWO_PAIR), bid=878)
// Game(hand=Hand(hand='34KK4', type=TWO_PAIR), bid=791)
// Game(hand=Hand(hand='35Q5Q', type=TWO_PAIR), bid=111)
// Game(hand=Hand(hand='37Q37', type=TWO_PAIR), bid=169)
// Game(hand=Hand(hand='3TJ3T', type=TWO_PAIR), bid=919)
// Game(hand=Hand(hand='3J99J', type=TWO_PAIR), bid=98)
// Game(hand=Hand(hand='3JTJ3', type=TWO_PAIR), bid=722)
// Game(hand=Hand(hand='3QT3Q', type=TWO_PAIR), bid=611)
// Game(hand=Hand(hand='3AQQ3', type=TWO_PAIR), bid=784)
// Game(hand=Hand(hand='44KK6', type=TWO_PAIR), bid=14)
// Game(hand=Hand(hand='455J4', type=TWO_PAIR), bid=550)
// Game(hand=Hand(hand='45K45', type=TWO_PAIR), bid=37)
// Game(hand=Hand(hand='4747T', type=TWO_PAIR), bid=26)
// Game(hand=Hand(hand='4T499', type=TWO_PAIR), bid=118)
// Game(hand=Hand(hand='4JJ4A', type=TWO_PAIR), bid=898)
// Game(hand=Hand(hand='4QQ34', type=TWO_PAIR), bid=745)
// Game(hand=Hand(hand='4K22K', type=TWO_PAIR), bid=541)
// Game(hand=Hand(hand='4K24K', type=TWO_PAIR), bid=826)
// Game(hand=Hand(hand='4K774', type=TWO_PAIR), bid=992)
// Game(hand=Hand(hand='4KK33', type=TWO_PAIR), bid=753)
// Game(hand=Hand(hand='4A664', type=TWO_PAIR), bid=952)
// Game(hand=Hand(hand='4AKAK', type=TWO_PAIR), bid=633)
// Game(hand=Hand(hand='52725', type=TWO_PAIR), bid=860)
// Game(hand=Hand(hand='53252', type=TWO_PAIR), bid=785)
// Game(hand=Hand(hand='53543', type=TWO_PAIR), bid=530)
// Game(hand=Hand(hand='54548', type=TWO_PAIR), bid=222)
// Game(hand=Hand(hand='55772', type=TWO_PAIR), bid=399)
// Game(hand=Hand(hand='557A7', type=TWO_PAIR), bid=834)
// Game(hand=Hand(hand='55992', type=TWO_PAIR), bid=586)
// Game(hand=Hand(hand='55A3A', type=TWO_PAIR), bid=868)
// Game(hand=Hand(hand='56568', type=TWO_PAIR), bid=397)
// Game(hand=Hand(hand='57J75', type=TWO_PAIR), bid=596)
// Game(hand=Hand(hand='57K5K', type=TWO_PAIR), bid=217)
// Game(hand=Hand(hand='58484', type=TWO_PAIR), bid=715)
// Game(hand=Hand(hand='599AA', type=TWO_PAIR), bid=172)
// Game(hand=Hand(hand='5T5TJ', type=TWO_PAIR), bid=184)
// Game(hand=Hand(hand='5TT5K', type=TWO_PAIR), bid=326)
// Game(hand=Hand(hand='5TTQ5', type=TWO_PAIR), bid=983)
// Game(hand=Hand(hand='5J52J', type=TWO_PAIR), bid=9)
// Game(hand=Hand(hand='5J599', type=TWO_PAIR), bid=912)
// Game(hand=Hand(hand='5QQ45', type=TWO_PAIR), bid=638)
// Game(hand=Hand(hand='5A5JA', type=TWO_PAIR), bid=738)
// Game(hand=Hand(hand='62K62', type=TWO_PAIR), bid=675)
// Game(hand=Hand(hand='66559', type=TWO_PAIR), bid=134)
// Game(hand=Hand(hand='667J7', type=TWO_PAIR), bid=871)
// Game(hand=Hand(hand='66J55', type=TWO_PAIR), bid=828)
// Game(hand=Hand(hand='66J88', type=TWO_PAIR), bid=895)
// Game(hand=Hand(hand='67464', type=TWO_PAIR), bid=297)
// Game(hand=Hand(hand='69692', type=TWO_PAIR), bid=294)
// Game(hand=Hand(hand='69776', type=TWO_PAIR), bid=684)
// Game(hand=Hand(hand='69868', type=TWO_PAIR), bid=322)
// Game(hand=Hand(hand='69889', type=TWO_PAIR), bid=741)
// Game(hand=Hand(hand='6Q62Q', type=TWO_PAIR), bid=437)
// Game(hand=Hand(hand='6QQTT', type=TWO_PAIR), bid=573)
// Game(hand=Hand(hand='6KK99', type=TWO_PAIR), bid=186)
// Game(hand=Hand(hand='6A9A9', type=TWO_PAIR), bid=348)
// Game(hand=Hand(hand='747J4', type=TWO_PAIR), bid=942)
// Game(hand=Hand(hand='75785', type=TWO_PAIR), bid=307)
// Game(hand=Hand(hand='772J2', type=TWO_PAIR), bid=788)
// Game(hand=Hand(hand='7788J', type=TWO_PAIR), bid=433)
// Game(hand=Hand(hand='79887', type=TWO_PAIR), bid=497)
// Game(hand=Hand(hand='7TKK7', type=TWO_PAIR), bid=336)
// Game(hand=Hand(hand='7JJT7', type=TWO_PAIR), bid=1)
// Game(hand=Hand(hand='7JJA7', type=TWO_PAIR), bid=619)
// Game(hand=Hand(hand='7K7QK', type=TWO_PAIR), bid=605)
// Game(hand=Hand(hand='7K7K6', type=TWO_PAIR), bid=121)
// Game(hand=Hand(hand='84AA8', type=TWO_PAIR), bid=985)
// Game(hand=Hand(hand='86678', type=TWO_PAIR), bid=428)
// Game(hand=Hand(hand='866AA', type=TWO_PAIR), bid=333)
// Game(hand=Hand(hand='87667', type=TWO_PAIR), bid=210)
// Game(hand=Hand(hand='878K7', type=TWO_PAIR), bid=381)
// Game(hand=Hand(hand='8899J', type=TWO_PAIR), bid=270)
// Game(hand=Hand(hand='88JTJ', type=TWO_PAIR), bid=518)
// Game(hand=Hand(hand='88AQQ', type=TWO_PAIR), bid=524)
// Game(hand=Hand(hand='89558', type=TWO_PAIR), bid=467)
// Game(hand=Hand(hand='89AA9', type=TWO_PAIR), bid=468)
// Game(hand=Hand(hand='8K83K', type=TWO_PAIR), bid=630)
// Game(hand=Hand(hand='94797', type=TWO_PAIR), bid=417)
// Game(hand=Hand(hand='9494J', type=TWO_PAIR), bid=901)
// Game(hand=Hand(hand='95596', type=TWO_PAIR), bid=276)
// Game(hand=Hand(hand='966Q9', type=TWO_PAIR), bid=41)
// Game(hand=Hand(hand='99644', type=TWO_PAIR), bid=964)
// Game(hand=Hand(hand='9T59T', type=TWO_PAIR), bid=833)
// Game(hand=Hand(hand='9T9KK', type=TWO_PAIR), bid=690)
// Game(hand=Hand(hand='9J9KK', type=TWO_PAIR), bid=765)
// Game(hand=Hand(hand='9K955', type=TWO_PAIR), bid=528)
// Game(hand=Hand(hand='9A33A', type=TWO_PAIR), bid=876)
// Game(hand=Hand(hand='9A88A', type=TWO_PAIR), bid=691)
// Game(hand=Hand(hand='T3366', type=TWO_PAIR), bid=197)
// Game(hand=Hand(hand='T34T4', type=TWO_PAIR), bid=520)
// Game(hand=Hand(hand='T35T3', type=TWO_PAIR), bid=221)
// Game(hand=Hand(hand='T44T9', type=TWO_PAIR), bid=503)
// Game(hand=Hand(hand='T66T7', type=TWO_PAIR), bid=332)
// Game(hand=Hand(hand='T6T22', type=TWO_PAIR), bid=931)
// Game(hand=Hand(hand='T733T', type=TWO_PAIR), bid=264)
// Game(hand=Hand(hand='T7JT7', type=TWO_PAIR), bid=744)
// Game(hand=Hand(hand='T88TJ', type=TWO_PAIR), bid=594)
// Game(hand=Hand(hand='T8T28', type=TWO_PAIR), bid=880)
// Game(hand=Hand(hand='T97T9', type=TWO_PAIR), bid=527)
// Game(hand=Hand(hand='TT4KK', type=TWO_PAIR), bid=501)
// Game(hand=Hand(hand='TT878', type=TWO_PAIR), bid=371)
// Game(hand=Hand(hand='TTKKA', type=TWO_PAIR), bid=193)
// Game(hand=Hand(hand='TJT22', type=TWO_PAIR), bid=664)
// Game(hand=Hand(hand='TJTJK', type=TWO_PAIR), bid=96)
// Game(hand=Hand(hand='TKQKT', type=TWO_PAIR), bid=260)
// Game(hand=Hand(hand='TA3AT', type=TWO_PAIR), bid=290)
// Game(hand=Hand(hand='TA6A6', type=TWO_PAIR), bid=46)
// Game(hand=Hand(hand='TA99A', type=TWO_PAIR), bid=712)
// Game(hand=Hand(hand='J272J', type=TWO_PAIR), bid=308)
// Game(hand=Hand(hand='J3377', type=TWO_PAIR), bid=877)
// Game(hand=Hand(hand='J339J', type=TWO_PAIR), bid=377)
// Game(hand=Hand(hand='J33KJ', type=TWO_PAIR), bid=587)
// Game(hand=Hand(hand='J3663', type=TWO_PAIR), bid=812)
// Game(hand=Hand(hand='J3JTT', type=TWO_PAIR), bid=89)
// Game(hand=Hand(hand='J4J4K', type=TWO_PAIR), bid=11)
// Game(hand=Hand(hand='J5TJ5', type=TWO_PAIR), bid=725)
// Game(hand=Hand(hand='J66J5', type=TWO_PAIR), bid=401)
// Game(hand=Hand(hand='J6Q6Q', type=TWO_PAIR), bid=843)
// Game(hand=Hand(hand='J737J', type=TWO_PAIR), bid=412)
// Game(hand=Hand(hand='J7997', type=TWO_PAIR), bid=601)
// Game(hand=Hand(hand='J7J72', type=TWO_PAIR), bid=480)
// Game(hand=Hand(hand='J88KK', type=TWO_PAIR), bid=623)
// Game(hand=Hand(hand='J99TT', type=TWO_PAIR), bid=987)
// Game(hand=Hand(hand='JTTKK', type=TWO_PAIR), bid=206)
// Game(hand=Hand(hand='JJ6Q6', type=TWO_PAIR), bid=714)
// Game(hand=Hand(hand='JJAAK', type=TWO_PAIR), bid=337)
// Game(hand=Hand(hand='JKJ4K', type=TWO_PAIR), bid=150)
// Game(hand=Hand(hand='JKKJ8', type=TWO_PAIR), bid=300)
// Game(hand=Hand(hand='JKKAA', type=TWO_PAIR), bid=159)
// Game(hand=Hand(hand='JAATT', type=TWO_PAIR), bid=706)
// Game(hand=Hand(hand='Q2QK2', type=TWO_PAIR), bid=748)
// Game(hand=Hand(hand='Q6TT6', type=TWO_PAIR), bid=574)
// Game(hand=Hand(hand='Q74Q4', type=TWO_PAIR), bid=490)
// Game(hand=Hand(hand='Q7JQ7', type=TWO_PAIR), bid=257)
// Game(hand=Hand(hand='Q7Q72', type=TWO_PAIR), bid=776)
// Game(hand=Hand(hand='Q828Q', type=TWO_PAIR), bid=231)
// Game(hand=Hand(hand='Q855Q', type=TWO_PAIR), bid=352)
// Game(hand=Hand(hand='Q99JQ', type=TWO_PAIR), bid=950)
// Game(hand=Hand(hand='QTT4Q', type=TWO_PAIR), bid=564)
// Game(hand=Hand(hand='QK3KQ', type=TWO_PAIR), bid=56)
// Game(hand=Hand(hand='QK55K', type=TWO_PAIR), bid=230)
// Game(hand=Hand(hand='QKQ4K', type=TWO_PAIR), bid=856)
// Game(hand=Hand(hand='K2255', type=TWO_PAIR), bid=971)
// Game(hand=Hand(hand='K2K2J', type=TWO_PAIR), bid=918)
// Game(hand=Hand(hand='K733K', type=TWO_PAIR), bid=793)
// Game(hand=Hand(hand='K7AA7', type=TWO_PAIR), bid=681)
// Game(hand=Hand(hand='K9977', type=TWO_PAIR), bid=789)
// Game(hand=Hand(hand='KJK44', type=TWO_PAIR), bid=631)
// Game(hand=Hand(hand='KK55J', type=TWO_PAIR), bid=455)
// Game(hand=Hand(hand='KAKTA', type=TWO_PAIR), bid=634)
// Game(hand=Hand(hand='KAKA8', type=TWO_PAIR), bid=380)
// Game(hand=Hand(hand='KAA99', type=TWO_PAIR), bid=67)
// Game(hand=Hand(hand='A52A2', type=TWO_PAIR), bid=636)
// Game(hand=Hand(hand='A662A', type=TWO_PAIR), bid=548)
// Game(hand=Hand(hand='A95A5', type=TWO_PAIR), bid=885)
// Game(hand=Hand(hand='A992A', type=TWO_PAIR), bid=613)
// Game(hand=Hand(hand='AJ8JA', type=TWO_PAIR), bid=16)
// Game(hand=Hand(hand='AQ99Q', type=TWO_PAIR), bid=263)
// Game(hand=Hand(hand='AQQ44', type=TWO_PAIR), bid=5)
// Game(hand=Hand(hand='AQQ77', type=TWO_PAIR), bid=202)
// Game(hand=Hand(hand='AKAK7', type=TWO_PAIR), bid=164)
// Game(hand=Hand(hand='AAQ4Q', type=TWO_PAIR), bid=39)
// Game(hand=Hand(hand='AAK22', type=TWO_PAIR), bid=819)
// Game(hand=Hand(hand='22297', type=THREE), bid=422)
// Game(hand=Hand(hand='222TJ', type=THREE), bid=375)
// Game(hand=Hand(hand='222KT', type=THREE), bid=589)
// Game(hand=Hand(hand='22627', type=THREE), bid=807)
// Game(hand=Hand(hand='22A26', type=THREE), bid=137)
// Game(hand=Hand(hand='23339', type=THREE), bid=682)
// Game(hand=Hand(hand='24944', type=THREE), bid=742)
// Game(hand=Hand(hand='24999', type=THREE), bid=933)
// Game(hand=Hand(hand='282T2', type=THREE), bid=506)
// Game(hand=Hand(hand='2TTAT', type=THREE), bid=91)
// Game(hand=Hand(hand='2J272', type=THREE), bid=110)
// Game(hand=Hand(hand='32888', type=THREE), bid=30)
// Game(hand=Hand(hand='33235', type=THREE), bid=80)
// Game(hand=Hand(hand='333TA', type=THREE), bid=557)
// Game(hand=Hand(hand='333J6', type=THREE), bid=178)
// Game(hand=Hand(hand='333KJ', type=THREE), bid=334)
// Game(hand=Hand(hand='33537', type=THREE), bid=993)
// Game(hand=Hand(hand='33J38', type=THREE), bid=165)
// Game(hand=Hand(hand='33AK3', type=THREE), bid=97)
// Game(hand=Hand(hand='353K3', type=THREE), bid=216)
// Game(hand=Hand(hand='3555J', type=THREE), bid=462)
// Game(hand=Hand(hand='36444', type=THREE), bid=90)
// Game(hand=Hand(hand='3666K', type=THREE), bid=430)
// Game(hand=Hand(hand='37877', type=THREE), bid=302)
// Game(hand=Hand(hand='3888K', type=THREE), bid=728)
// Game(hand=Hand(hand='388A8', type=THREE), bid=873)
// Game(hand=Hand(hand='39222', type=THREE), bid=387)
// Game(hand=Hand(hand='3T999', type=THREE), bid=225)
// Game(hand=Hand(hand='3T9TT', type=THREE), bid=441)
// Game(hand=Hand(hand='3J3A3', type=THREE), bid=965)
// Game(hand=Hand(hand='3JAAA', type=THREE), bid=892)
// Game(hand=Hand(hand='3KKK2', type=THREE), bid=979)
// Game(hand=Hand(hand='3AA6A', type=THREE), bid=359)
// Game(hand=Hand(hand='42622', type=THREE), bid=680)
// Game(hand=Hand(hand='44342', type=THREE), bid=969)
// Game(hand=Hand(hand='4484J', type=THREE), bid=292)
// Game(hand=Hand(hand='44JQ4', type=THREE), bid=306)
// Game(hand=Hand(hand='499J9', type=THREE), bid=556)
// Game(hand=Hand(hand='4T222', type=THREE), bid=493)
// Game(hand=Hand(hand='4T448', type=THREE), bid=175)
// Game(hand=Hand(hand='4J222', type=THREE), bid=299)
// Game(hand=Hand(hand='4J4T4', type=THREE), bid=821)
// Game(hand=Hand(hand='4A447', type=THREE), bid=182)
// Game(hand=Hand(hand='53595', type=THREE), bid=385)
// Game(hand=Hand(hand='535T5', type=THREE), bid=1000)
// Game(hand=Hand(hand='5558J', type=THREE), bid=470)
// Game(hand=Hand(hand='555J4', type=THREE), bid=872)
// Game(hand=Hand(hand='5565K', type=THREE), bid=835)
// Game(hand=Hand(hand='556Q5', type=THREE), bid=707)
// Game(hand=Hand(hand='55754', type=THREE), bid=396)
// Game(hand=Hand(hand='55T59', type=THREE), bid=599)
// Game(hand=Hand(hand='55J52', type=THREE), bid=817)
// Game(hand=Hand(hand='55A5T', type=THREE), bid=315)
// Game(hand=Hand(hand='56667', type=THREE), bid=532)
// Game(hand=Hand(hand='5666K', type=THREE), bid=953)
// Game(hand=Hand(hand='56999', type=THREE), bid=796)
// Game(hand=Hand(hand='58KKK', type=THREE), bid=269)
// Game(hand=Hand(hand='5T3TT', type=THREE), bid=639)
// Game(hand=Hand(hand='5TT7T', type=THREE), bid=235)
// Game(hand=Hand(hand='5A552', type=THREE), bid=787)
// Game(hand=Hand(hand='62252', type=THREE), bid=214)
// Game(hand=Hand(hand='6444K', type=THREE), bid=409)
// Game(hand=Hand(hand='65668', type=THREE), bid=929)
// Game(hand=Hand(hand='65669', type=THREE), bid=492)
// Game(hand=Hand(hand='66689', type=THREE), bid=861)
// Game(hand=Hand(hand='677A7', type=THREE), bid=195)
// Game(hand=Hand(hand='6T766', type=THREE), bid=423)
// Game(hand=Hand(hand='6J668', type=THREE), bid=597)
// Game(hand=Hand(hand='6QQQ8', type=THREE), bid=780)
// Game(hand=Hand(hand='6AATA', type=THREE), bid=649)
// Game(hand=Hand(hand='72666', type=THREE), bid=499)
// Game(hand=Hand(hand='7277K', type=THREE), bid=507)
// Game(hand=Hand(hand='73677', type=THREE), bid=261)
// Game(hand=Hand(hand='74778', type=THREE), bid=141)
// Game(hand=Hand(hand='74J77', type=THREE), bid=775)
// Game(hand=Hand(hand='75A55', type=THREE), bid=17)
// Game(hand=Hand(hand='7666Q', type=THREE), bid=739)
// Game(hand=Hand(hand='77572', type=THREE), bid=350)
// Game(hand=Hand(hand='7773T', type=THREE), bid=693)
// Game(hand=Hand(hand='777J6', type=THREE), bid=510)
// Game(hand=Hand(hand='777K9', type=THREE), bid=662)
// Game(hand=Hand(hand='77872', type=THREE), bid=920)
// Game(hand=Hand(hand='77Q57', type=THREE), bid=568)
// Game(hand=Hand(hand='77Q73', type=THREE), bid=338)
// Game(hand=Hand(hand='7T779', type=THREE), bid=914)
// Game(hand=Hand(hand='83488', type=THREE), bid=536)
// Game(hand=Hand(hand='83K33', type=THREE), bid=505)
// Game(hand=Hand(hand='85955', type=THREE), bid=549)
// Game(hand=Hand(hand='85T88', type=THREE), bid=866)
// Game(hand=Hand(hand='86K66', type=THREE), bid=947)
// Game(hand=Hand(hand='88785', type=THREE), bid=575)
// Game(hand=Hand(hand='88826', type=THREE), bid=907)
// Game(hand=Hand(hand='88836', type=THREE), bid=846)
// Game(hand=Hand(hand='889J8', type=THREE), bid=298)
// Game(hand=Hand(hand='88Q85', type=THREE), bid=108)
// Game(hand=Hand(hand='89488', type=THREE), bid=779)
// Game(hand=Hand(hand='8Q88A', type=THREE), bid=771)
// Game(hand=Hand(hand='8QQQA', type=THREE), bid=767)
// Game(hand=Hand(hand='8A878', type=THREE), bid=955)
// Game(hand=Hand(hand='8A8T8', type=THREE), bid=648)
// Game(hand=Hand(hand='8AA5A', type=THREE), bid=188)
// Game(hand=Hand(hand='92699', type=THREE), bid=799)
// Game(hand=Hand(hand='92K99', type=THREE), bid=29)
// Game(hand=Hand(hand='93J99', type=THREE), bid=683)
// Game(hand=Hand(hand='95777', type=THREE), bid=781)
// Game(hand=Hand(hand='997J9', type=THREE), bid=51)
// Game(hand=Hand(hand='99839', type=THREE), bid=961)
// Game(hand=Hand(hand='9T5TT', type=THREE), bid=282)
// Game(hand=Hand(hand='9J599', type=THREE), bid=483)
// Game(hand=Hand(hand='9J969', type=THREE), bid=226)
// Game(hand=Hand(hand='9K959', type=THREE), bid=928)
// Game(hand=Hand(hand='9KQ99', type=THREE), bid=808)
// Game(hand=Hand(hand='9KQKK', type=THREE), bid=311)
// Game(hand=Hand(hand='T23TT', type=THREE), bid=357)
// Game(hand=Hand(hand='T2TTQ', type=THREE), bid=547)
// Game(hand=Hand(hand='T2KTT', type=THREE), bid=660)
// Game(hand=Hand(hand='T3933', type=THREE), bid=456)
// Game(hand=Hand(hand='T3T6T', type=THREE), bid=78)
// Game(hand=Hand(hand='T4888', type=THREE), bid=750)
// Game(hand=Hand(hand='T5TT4', type=THREE), bid=451)
// Game(hand=Hand(hand='T6555', type=THREE), bid=650)
// Game(hand=Hand(hand='T66J6', type=THREE), bid=127)
// Game(hand=Hand(hand='T7776', type=THREE), bid=526)
// Game(hand=Hand(hand='T8TT5', type=THREE), bid=736)
// Game(hand=Hand(hand='T8TTQ', type=THREE), bid=22)
// Game(hand=Hand(hand='T96TT', type=THREE), bid=849)
// Game(hand=Hand(hand='TT4AT', type=THREE), bid=679)
// Game(hand=Hand(hand='TT92T', type=THREE), bid=830)
// Game(hand=Hand(hand='TTT52', type=THREE), bid=773)
// Game(hand=Hand(hand='TTT72', type=THREE), bid=259)
// Game(hand=Hand(hand='TTJ9T', type=THREE), bid=887)
// Game(hand=Hand(hand='TTKT8', type=THREE), bid=356)
// Game(hand=Hand(hand='TTA9T', type=THREE), bid=894)
// Game(hand=Hand(hand='TQJTT', type=THREE), bid=394)
// Game(hand=Hand(hand='TK777', type=THREE), bid=153)
// Game(hand=Hand(hand='TKQTT', type=THREE), bid=588)
// Game(hand=Hand(hand='TKKKQ', type=THREE), bid=802)
// Game(hand=Hand(hand='J333Q', type=THREE), bid=814)
// Game(hand=Hand(hand='J3888', type=THREE), bid=345)
// Game(hand=Hand(hand='J4442', type=THREE), bid=406)
// Game(hand=Hand(hand='J6662', type=THREE), bid=200)
// Game(hand=Hand(hand='J6J7J', type=THREE), bid=18)
// Game(hand=Hand(hand='J777Q', type=THREE), bid=489)
// Game(hand=Hand(hand='J8788', type=THREE), bid=88)
// Game(hand=Hand(hand='JJ4QJ', type=THREE), bid=954)
// Game(hand=Hand(hand='JQJ9J', type=THREE), bid=508)
// Game(hand=Hand(hand='JATTT', type=THREE), bid=310)
// Game(hand=Hand(hand='JAA2A', type=THREE), bid=592)
// Game(hand=Hand(hand='Q5666', type=THREE), bid=731)
// Game(hand=Hand(hand='Q6KQQ', type=THREE), bid=38)
// Game(hand=Hand(hand='Q777A', type=THREE), bid=884)
// Game(hand=Hand(hand='Q7797', type=THREE), bid=705)
// Game(hand=Hand(hand='Q7QJQ', type=THREE), bid=281)
// Game(hand=Hand(hand='Q7QAQ', type=THREE), bid=161)
// Game(hand=Hand(hand='Q8878', type=THREE), bid=610)
// Game(hand=Hand(hand='Q8QQJ', type=THREE), bid=65)
// Game(hand=Hand(hand='QJ6QQ', type=THREE), bid=95)
// Game(hand=Hand(hand='QJQQT', type=THREE), bid=724)
// Game(hand=Hand(hand='QQ3Q6', type=THREE), bid=429)
// Game(hand=Hand(hand='QQQ24', type=THREE), bid=709)
// Game(hand=Hand(hand='QQQ2J', type=THREE), bid=323)
// Game(hand=Hand(hand='QQQ9J', type=THREE), bid=421)
// Game(hand=Hand(hand='QAAA5', type=THREE), bid=523)
// Game(hand=Hand(hand='K22Q2', type=THREE), bid=743)
// Game(hand=Hand(hand='K3AKK', type=THREE), bid=703)
// Game(hand=Hand(hand='K4777', type=THREE), bid=921)
// Game(hand=Hand(hand='K4KK5', type=THREE), bid=916)
// Game(hand=Hand(hand='K5T55', type=THREE), bid=76)
// Game(hand=Hand(hand='K7KK4', type=THREE), bid=2)
// Game(hand=Hand(hand='K8488', type=THREE), bid=160)
// Game(hand=Hand(hand='K9997', type=THREE), bid=220)
// Game(hand=Hand(hand='K9J99', type=THREE), bid=384)
// Game(hand=Hand(hand='K9KK7', type=THREE), bid=449)
// Game(hand=Hand(hand='KT8KK', type=THREE), bid=42)
// Game(hand=Hand(hand='KTKK5', type=THREE), bid=4)
// Game(hand=Hand(hand='KQQ4Q', type=THREE), bid=581)
// Game(hand=Hand(hand='KQKK3', type=THREE), bid=162)
// Game(hand=Hand(hand='KK3K5', type=THREE), bid=194)
// Game(hand=Hand(hand='KK4QK', type=THREE), bid=280)
// Game(hand=Hand(hand='KKJK2', type=THREE), bid=53)
// Game(hand=Hand(hand='KKJK6', type=THREE), bid=957)
// Game(hand=Hand(hand='KKK72', type=THREE), bid=746)
// Game(hand=Hand(hand='KKKJ4', type=THREE), bid=540)
// Game(hand=Hand(hand='KKKAJ', type=THREE), bid=339)
// Game(hand=Hand(hand='A8AQA', type=THREE), bid=670)
// Game(hand=Hand(hand='AJAA4', type=THREE), bid=593)
// Game(hand=Hand(hand='AQAAT', type=THREE), bid=116)
// Game(hand=Hand(hand='AA43A', type=THREE), bid=831)
// Game(hand=Hand(hand='AA4QA', type=THREE), bid=288)
// Game(hand=Hand(hand='AA7A4', type=THREE), bid=667)
// Game(hand=Hand(hand='AAAJ5', type=THREE), bid=606)
// Game(hand=Hand(hand='222TT', type=FULL), bid=248)
// Game(hand=Hand(hand='22777', type=FULL), bid=12)
// Game(hand=Hand(hand='26266', type=FULL), bid=163)
// Game(hand=Hand(hand='27227', type=FULL), bid=291)
// Game(hand=Hand(hand='34433', type=FULL), bid=439)
// Game(hand=Hand(hand='34434', type=FULL), bid=538)
// Game(hand=Hand(hand='39993', type=FULL), bid=544)
// Game(hand=Hand(hand='3KKK3', type=FULL), bid=845)
// Game(hand=Hand(hand='42424', type=FULL), bid=283)
// Game(hand=Hand(hand='444TT', type=FULL), bid=185)
// Game(hand=Hand(hand='44555', type=FULL), bid=191)
// Game(hand=Hand(hand='44884', type=FULL), bid=624)
// Game(hand=Hand(hand='48884', type=FULL), bid=940)
// Game(hand=Hand(hand='4TT4T', type=FULL), bid=420)
// Game(hand=Hand(hand='4Q4QQ', type=FULL), bid=416)
// Game(hand=Hand(hand='4AA44', type=FULL), bid=645)
// Game(hand=Hand(hand='55QQ5', type=FULL), bid=647)
// Game(hand=Hand(hand='58558', type=FULL), bid=25)
// Game(hand=Hand(hand='5TT55', type=FULL), bid=77)
// Game(hand=Hand(hand='5QQ5Q', type=FULL), bid=418)
// Game(hand=Hand(hand='62622', type=FULL), bid=534)
// Game(hand=Hand(hand='64464', type=FULL), bid=800)
// Game(hand=Hand(hand='65565', type=FULL), bid=419)
// Game(hand=Hand(hand='65656', type=FULL), bid=496)
// Game(hand=Hand(hand='66333', type=FULL), bid=434)
// Game(hand=Hand(hand='66644', type=FULL), bid=642)
// Game(hand=Hand(hand='68688', type=FULL), bid=792)
// Game(hand=Hand(hand='6TT6T', type=FULL), bid=242)
// Game(hand=Hand(hand='75557', type=FULL), bid=863)
// Game(hand=Hand(hand='76677', type=FULL), bid=996)
// Game(hand=Hand(hand='77373', type=FULL), bid=43)
// Game(hand=Hand(hand='77755', type=FULL), bid=848)
// Game(hand=Hand(hand='777TT', type=FULL), bid=737)
// Game(hand=Hand(hand='777JJ', type=FULL), bid=906)
// Game(hand=Hand(hand='82822', type=FULL), bid=591)
// Game(hand=Hand(hand='88777', type=FULL), bid=131)
// Game(hand=Hand(hand='88822', type=FULL), bid=130)
// Game(hand=Hand(hand='888TT', type=FULL), bid=875)
// Game(hand=Hand(hand='89989', type=FULL), bid=858)
// Game(hand=Hand(hand='92922', type=FULL), bid=128)
// Game(hand=Hand(hand='93339', type=FULL), bid=475)
// Game(hand=Hand(hand='96966', type=FULL), bid=132)
// Game(hand=Hand(hand='98988', type=FULL), bid=140)
// Game(hand=Hand(hand='99555', type=FULL), bid=346)
// Game(hand=Hand(hand='99779', type=FULL), bid=379)
// Game(hand=Hand(hand='99J9J', type=FULL), bid=805)
// Game(hand=Hand(hand='9T9T9', type=FULL), bid=100)
// Game(hand=Hand(hand='9K99K', type=FULL), bid=803)
// Game(hand=Hand(hand='T6T66', type=FULL), bid=252)
// Game(hand=Hand(hand='T9TT9', type=FULL), bid=109)
// Game(hand=Hand(hand='TT77T', type=FULL), bid=33)
// Game(hand=Hand(hand='TKTKT', type=FULL), bid=343)
// Game(hand=Hand(hand='J33J3', type=FULL), bid=452)
// Game(hand=Hand(hand='J44J4', type=FULL), bid=247)
// Game(hand=Hand(hand='J555J', type=FULL), bid=330)
// Game(hand=Hand(hand='J6J66', type=FULL), bid=365)
// Game(hand=Hand(hand='J8JJ8', type=FULL), bid=240)
// Game(hand=Hand(hand='JTTTJ', type=FULL), bid=628)
// Game(hand=Hand(hand='JJ222', type=FULL), bid=83)
// Game(hand=Hand(hand='JJ888', type=FULL), bid=488)
// Game(hand=Hand(hand='JJTTJ', type=FULL), bid=717)
// Game(hand=Hand(hand='JQQJQ', type=FULL), bid=171)
// Game(hand=Hand(hand='Q2Q22', type=FULL), bid=404)
// Game(hand=Hand(hand='Q333Q', type=FULL), bid=571)
// Game(hand=Hand(hand='Q7Q77', type=FULL), bid=232)
// Game(hand=Hand(hand='Q7QQ7', type=FULL), bid=837)
// Game(hand=Hand(hand='Q888Q', type=FULL), bid=757)
// Game(hand=Hand(hand='QQ6Q6', type=FULL), bid=241)
// Game(hand=Hand(hand='QQQ99', type=FULL), bid=361)
// Game(hand=Hand(hand='QKQQK', type=FULL), bid=158)
// Game(hand=Hand(hand='K2K2K', type=FULL), bid=577)
// Game(hand=Hand(hand='K33K3', type=FULL), bid=372)
// Game(hand=Hand(hand='K66K6', type=FULL), bid=612)
// Game(hand=Hand(hand='KTKTK', type=FULL), bid=836)
// Game(hand=Hand(hand='KJJKK', type=FULL), bid=999)
// Game(hand=Hand(hand='KKQQK', type=FULL), bid=842)
// Game(hand=Hand(hand='KKK88', type=FULL), bid=522)
// Game(hand=Hand(hand='A3A3A', type=FULL), bid=444)
// Game(hand=Hand(hand='A4A4A', type=FULL), bid=583)
// Game(hand=Hand(hand='A555A', type=FULL), bid=335)
// Game(hand=Hand(hand='A88A8', type=FULL), bid=945)
// Game(hand=Hand(hand='A99AA', type=FULL), bid=145)
// Game(hand=Hand(hand='AQAQA', type=FULL), bid=626)
// Game(hand=Hand(hand='AKAKK', type=FULL), bid=685)
// Game(hand=Hand(hand='AA88A', type=FULL), bid=646)
// Game(hand=Hand(hand='AAJJA', type=FULL), bid=622)
// Game(hand=Hand(hand='AAQQQ', type=FULL), bid=572)
// Game(hand=Hand(hand='AAATT', type=FULL), bid=655)
// Game(hand=Hand(hand='22226', type=KARE), bid=391)
// Game(hand=Hand(hand='22232', type=KARE), bid=223)
// Game(hand=Hand(hand='22252', type=KARE), bid=566)
// Game(hand=Hand(hand='22272', type=KARE), bid=823)
// Game(hand=Hand(hand='22292', type=KARE), bid=50)
// Game(hand=Hand(hand='222J2', type=KARE), bid=254)
// Game(hand=Hand(hand='222Q2', type=KARE), bid=804)
// Game(hand=Hand(hand='23333', type=KARE), bid=632)
// Game(hand=Hand(hand='28888', type=KARE), bid=19)
// Game(hand=Hand(hand='3333Q', type=KARE), bid=239)
// Game(hand=Hand(hand='3333K', type=KARE), bid=142)
// Game(hand=Hand(hand='33353', type=KARE), bid=431)
// Game(hand=Hand(hand='33J33', type=KARE), bid=968)
// Game(hand=Hand(hand='39999', type=KARE), bid=363)
// Game(hand=Hand(hand='3T333', type=KARE), bid=318)
// Game(hand=Hand(hand='42444', type=KARE), bid=82)
// Game(hand=Hand(hand='44447', type=KARE), bid=192)
// Game(hand=Hand(hand='4444Q', type=KARE), bid=560)
// Game(hand=Hand(hand='44644', type=KARE), bid=759)
// Game(hand=Hand(hand='44844', type=KARE), bid=402)
// Game(hand=Hand(hand='47777', type=KARE), bid=770)
// Game(hand=Hand(hand='4J444', type=KARE), bid=482)
// Game(hand=Hand(hand='4KKKK', type=KARE), bid=369)
// Game(hand=Hand(hand='54444', type=KARE), bid=504)
// Game(hand=Hand(hand='55455', type=KARE), bid=735)
// Game(hand=Hand(hand='5555J', type=KARE), bid=732)
// Game(hand=Hand(hand='55575', type=KARE), bid=119)
// Game(hand=Hand(hand='555Q5', type=KARE), bid=937)
// Game(hand=Hand(hand='55655', type=KARE), bid=148)
// Game(hand=Hand(hand='5K555', type=KARE), bid=44)
// Game(hand=Hand(hand='5AAAA', type=KARE), bid=265)
// Game(hand=Hand(hand='62666', type=KARE), bid=590)
// Game(hand=Hand(hand='63333', type=KARE), bid=990)
// Game(hand=Hand(hand='66466', type=KARE), bid=844)
// Game(hand=Hand(hand='66663', type=KARE), bid=674)
// Game(hand=Hand(hand='66667', type=KARE), bid=811)
// Game(hand=Hand(hand='6666J', type=KARE), bid=595)
// Game(hand=Hand(hand='66866', type=KARE), bid=425)
// Game(hand=Hand(hand='6T666', type=KARE), bid=293)
// Game(hand=Hand(hand='6TTTT', type=KARE), bid=502)
// Game(hand=Hand(hand='72777', type=KARE), bid=883)
// Game(hand=Hand(hand='77577', type=KARE), bid=910)
// Game(hand=Hand(hand='7777Q', type=KARE), bid=825)
// Game(hand=Hand(hand='7777A', type=KARE), bid=28)
// Game(hand=Hand(hand='777T7', type=KARE), bid=445)
// Game(hand=Hand(hand='77977', type=KARE), bid=395)
// Game(hand=Hand(hand='77K77', type=KARE), bid=822)
// Game(hand=Hand(hand='82222', type=KARE), bid=61)
// Game(hand=Hand(hand='88488', type=KARE), bid=777)
// Game(hand=Hand(hand='88887', type=KARE), bid=327)
// Game(hand=Hand(hand='8888T', type=KARE), bid=615)
// Game(hand=Hand(hand='888J8', type=KARE), bid=629)
// Game(hand=Hand(hand='8Q888', type=KARE), bid=893)
// Game(hand=Hand(hand='8A888', type=KARE), bid=832)
// Game(hand=Hand(hand='95999', type=KARE), bid=390)
// Game(hand=Hand(hand='98999', type=KARE), bid=915)
// Game(hand=Hand(hand='99299', type=KARE), bid=862)
// Game(hand=Hand(hand='99699', type=KARE), bid=459)
// Game(hand=Hand(hand='9999T', type=KARE), bid=519)
// Game(hand=Hand(hand='999Q9', type=KARE), bid=604)
// Game(hand=Hand(hand='T2222', type=KARE), bid=366)
// Game(hand=Hand(hand='TT4TT', type=KARE), bid=35)
// Game(hand=Hand(hand='TT8TT', type=KARE), bid=766)
// Game(hand=Hand(hand='TTTT3', type=KARE), bid=312)
// Game(hand=Hand(hand='TTTTJ', type=KARE), bid=52)
// Game(hand=Hand(hand='TTATT', type=KARE), bid=317)
// Game(hand=Hand(hand='TQQQQ', type=KARE), bid=951)
// Game(hand=Hand(hand='TKTTT', type=KARE), bid=688)
// Game(hand=Hand(hand='J7777', type=KARE), bid=865)
// Game(hand=Hand(hand='J9999', type=KARE), bid=233)
// Game(hand=Hand(hand='JJJJ8', type=KARE), bid=154)
// Game(hand=Hand(hand='Q4QQQ', type=KARE), bid=382)
// Game(hand=Hand(hand='Q6666', type=KARE), bid=136)
// Game(hand=Hand(hand='Q6QQQ', type=KARE), bid=824)
// Game(hand=Hand(hand='Q9QQQ', type=KARE), bid=374)
// Game(hand=Hand(hand='QQJQQ', type=KARE), bid=730)
// Game(hand=Hand(hand='QQQQ5', type=KARE), bid=57)
// Game(hand=Hand(hand='QQQKQ', type=KARE), bid=386)
// Game(hand=Hand(hand='K6KKK', type=KARE), bid=818)
// Game(hand=Hand(hand='K7KKK', type=KARE), bid=600)
// Game(hand=Hand(hand='K8888', type=KARE), bid=27)
// Game(hand=Hand(hand='K9999', type=KARE), bid=661)
// Game(hand=Hand(hand='KJKKK', type=KARE), bid=909)
// Game(hand=Hand(hand='KK9KK', type=KARE), bid=457)
// Game(hand=Hand(hand='KKTKK', type=KARE), bid=576)
// Game(hand=Hand(hand='KKQKK', type=KARE), bid=934)
// Game(hand=Hand(hand='KKKK8', type=KARE), bid=303)
// Game(hand=Hand(hand='KKAKK', type=KARE), bid=376)
// Game(hand=Hand(hand='KAAAA', type=KARE), bid=525)
// Game(hand=Hand(hand='A3333', type=KARE), bid=442)
// Game(hand=Hand(hand='AJAAA', type=KARE), bid=855)
// Game(hand=Hand(hand='AA3AA', type=KARE), bid=696)
// Game(hand=Hand(hand='AA4AA', type=KARE), bid=362)
// Game(hand=Hand(hand='AA8AA', type=KARE), bid=794)
// Game(hand=Hand(hand='AAA7A', type=KARE), bid=747)
// Game(hand=Hand(hand='JJJJJ', type=FLUSH), bid=435)
// 249638405
